# %% [markdown]
# Тематическое моделирование на своем датасете: использование модели LDA, визуализация топиков, построение тематических профилей.
# Цель: Боевой проект по тематическому моделированию. Цель - построить LDA модель и получить интерпретируемые топики. Попробовать посчитать тематические профили и получить их визуализацию на двумерной плоскости при помощи TSNE
# В материалах вы можете найти выгрузку комментариев из разных музыкальных групп ВК, в полях music_style и performer можно получить информацию о конкретном музыкальном жанре и исполнителе, в группе которого был написан комментарий. Выгрузка уменьшенная, остались только комментарии длиной больше 40 слов, но тем не менее это всё ещё 500Мб, так что модельки будут считаться долго. Для отладки рекомендую брать небольшую выборку из этого датасета, чтобы на ней тестировать свой код.
#
# Если у вас есть собственный датасет - можно (и будет очень круто) использовать его :)
#
# 1. Загрузите датасет. Если используете данные вк, то после загрузки воспользуйтесь следующим кодом:
#
# from ast import literal_eval
# bag_of_words = data.text_bow.apply(literal_eval)
#
# где data - это загруженный датасет. Операция необходима, так как предварительно уже была проведена предобработка текстов и получено представление bag-of-words, так что остаётся его лишь прочитать из датасета
#
# 2. Используя gensim, добавьте биграммы к имеющемуся bag_of_words представлению
#
# 3. Составьте словарь из терминов (corpora.Dictionary)
#
# 4. По словарю терминов при помощи метода filter_extremes проведите фильтрацию слов по частоте встречаемости. На данных вк рекомендую следующие параметры: (no_below=3, no_above=0.4, keep_n=3*10**6)
#
# 5. Наконец, составьте итоговый корпус документов при помощи метода doc2bow. Рекомендую его сохранить (например, в pickle формате), на случай, если что-то где-то пойдет не так
#
# 6. По получившемуся корпусу постройте LDA модель, если используете данные вк, рекомендую параметры (eval_every=20, num_topics=30, passes=5). Не забудьте сохранить саму модель и её аттрибут expElogBeta, также при помощи метода show_topics возьмите по 100 самых вероятных слов для каждой темы
#
# 7. При помощи wordcloud визуализируйте каждый из получившихся топиков и попробуйте их проинтерпретировать. Чтобы не возиться долго с функциями для визуализации, можно взять их отсюда - https://github.com/DmitrySerg/top-russian-music/blob/master/models/clean_visualization.ipynb
#
# 8. Наконец, постройте тематические профили по интересующим вас группировкам (в случае с вк можно построить средние тематические вектора по жанрам или по исполнителям, если у вас собственные данные, попробуйте подумать, как можно было бы сгруппировать ваши документы, чтобы все-таки построить профили групп), и визуализируйте их при помощи TSNE
#
# 9. Вы великолепны
# Критерии оценки: Получилось построить LDA и хотя бы в текстовом формате показать наиболее характерные для каждого топика слова - 5 баллов
#
# Есть визуализация wordcloud +2 балла
#
# Есть визуализация TSNE для тематических профилей +3 балла

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import json

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Пару занятий назад спарсил местный сайт новостей, его и буду мучить. Цель - по тексту новости найти темы и сравнить их с реальными рубриками.

# %%
data = pd.read_csv('ngsnews.csv', sep=';')

# %%
data.head()
# Out:
#    Unnamed: 0               parced                                  link  \
# 0           0  2020-02-08 13:52:56  https://ngs24.ru/news/more/66485668/
# 1           1  2020-02-08 13:52:56  https://ngs24.ru/news/more/66485626/
# 2           2  2020-02-08 13:52:58  https://ngs24.ru/news/more/66485617/
# 3           3  2020-02-08 13:52:59  https://ngs24.ru/news/more/66485605/
# 4           4  2020-02-08 13:53:01  https://ngs24.ru/news/more/66485599/
#
#               datenews                                           headline  \
# 0  2020-02-08 12:42:26  Красноярская активистка направила обращение в ...
# 1  2020-02-08 11:32:39  Молодые красноярцы сняли квартиру и оборудовал...
# 2  2020-02-08 10:42:55  С ж/д моста на Свободном оторвалась балка и на...
# 3  2020-02-08 10:23:29  «Это грубое вторжение человека в экологию»: же...
# 4  2020-02-08 09:34:17  Красноярец прошелся по капоту припаркованного ...
#
#                                      altheadline  \
# 0      Ответ аппарата правительства ее рассмешил
# 1                       Им грозит 20 лет колонии
# 2             На месте работают сотрудники ГИБДД
# 3          Она предложила лечить его гомеопатией
# 4  Машина стояла припаркованной вплотную к стене
#
#                                          txtnewsfull  views  comments  \
# 0  Лаборатория должна появиться в горах в 6 км от...    703         9
# 1  Найденная коробка со всякими веществами и один...   1863         4
# 2  Балка опасно повисла над проезжей частью Фото:...   1905         7
# 3  Наталья Толоконская — врач в Новосибирском гом...   1192        16
# 4  Задуманное молодому человеку удалось осуществи...   3181        14
#
#                              rating                           rubric  \
# 0  ЛАЙК1СМЕХ1УДИВЛЕНИЕ0ГНЕВ0ПЕЧАЛЬ0                            Город
# 1  ЛАЙК0СМЕХ0УДИВЛЕНИЕ0ГНЕВ0ПЕЧАЛЬ0                         Криминал
# 2  ЛАЙК0СМЕХ0УДИВЛЕНИЕ1ГНЕВ2ПЕЧАЛЬ0                     Происшествия
# 3  ЛАЙК2СМЕХ0УДИВЛЕНИЕ0ГНЕВ0ПЕЧАЛЬ0  Здоровье  Китайский коронавирус
# 4  ЛАЙК8СМЕХ3УДИВЛЕНИЕ1ГНЕВ2ПЕЧАЛЬ1               Дороги и транспорт
#
#                                                 tags
# 0  #Наталия Подоляк, #ядерное хранилище, #Краснод...
# 1                                 #нарколаборатория,
# 2                                       #балка, #ЧП,
# 3                 #гомеопатия, #Наталья Толоконская,
# 4                                         #парковка,

# %% [markdown]
#  собираем  текст новости  с  заголовком, подзаголовком  и собственно текстом  и очищаем от пунктуации, переводим в нижний регистр

# %%
import re
def strip_punctuation(string):
    return re.sub(r'[^\w\s]', '', string.lower())

data['text'] = data['headline'].fillna(" ") + ' ' + data['altheadline'].fillna(" ") + ' ' + data['txtnewsfull'].fillna(" ")
data['text'] = data['text'].apply(strip_punctuation)

print(data.text)
data.head(1).T
# Out:
# 0      красноярская активистка направила обращение в ...
# 1      молодые красноярцы сняли квартиру и оборудовал...
# 2      с жд моста на свободном оторвалась балка и нав...
# 3      это грубое вторжение человека в экологию жена ...
# 4      красноярец прошелся по капоту припаркованного ...
# 5      под казанью на частном вертолете разбился депу...
# 6      спасатели показали как вытаскивают со дна зато...
# 7      чаще всего жертвами становятся молодые мамы ин...
# 8      суд присяжных оправдал парня убившего свою баб...
# 9      в бсмп прошли учения по приемке пациентов с ко...
# 10     вторые в мире по загрязнению вчерашний смог вы...
# 11     запрет youtube угроза штрафа за датчики и увол...
# 12     на младенца упал баллон с гелием девочка борол...
# 13     плати или 12 лет по делу эксдепутата аркадия в...
# 14     попытался убить и обокрал дивногорца приговори...
# 15     80летний пенсионер из красноярска устраивает м...
# 16     красноярских детей начали закалять от орви йог...
# 17     главный прокурор края уходит в отставку источн...
# 18     телефонный мошенник под личиной банковского ра...
# 19     в сибгу им решетнева прошли обыски по данным т...
# 20     надбавка к алиментам путин обязал родителей об...
# 21     на выходных красноярцы смогут наблюдать рекорд...
# 22     в красноярске в мусоропровод выкинули крольчих...
# 23     красноярка перестала платить за коммуналку и к...
# 24     едкую дымку сдуло из города воздух в городе по...
# 25     бойтесь панков и китов как учителей учат борот...
# 26     в красноярске пропал высокий 16летний подросто...
# 27     мы вытащили новый suzuki jimny на военный поли...
# 28     ночью в серьезном пожаре выгорело бесхозное зд...
# 29     в красноярске ожидаются очень теплые выходные ...
#                              ...
# 635    красноярец прошелся по капоту припаркованного ...
# 636    под казанью на частном вертолете разбился депу...
# 637    спасатели показали как вытаскивают со дна зато...
# 638    чаще всего жертвами становятся молодые мамы ин...
# 639    суд присяжных оправдал парня убившего свою баб...
# 640    в бсмп прошли учения по приемке пациентов с ко...
# 641    вторые в мире по загрязнению вчерашний смог вы...
# 642    запрет youtube угроза штрафа за датчики и увол...
# 643    на младенца упал баллон с гелием девочка борол...
# 644    плати или 12 лет по делу эксдепутата аркадия в...
# 645    попытался убить и обокрал дивногорца приговори...
# 646    80летний пенсионер из красноярска устраивает м...
# 647    красноярских детей начали закалять от орви йог...
# 648    главный прокурор края уходит в отставку источн...
# 649    телефонный мошенник под личиной банковского ра...
# 650    в сибгу им решетнева прошли обыски по данным т...
# 651    надбавка к алиментам путин обязал родителей об...
# 652    на выходных красноярцы смогут наблюдать рекорд...
# 653    в красноярске в мусоропровод выкинули крольчих...
# 654    красноярка перестала платить за коммуналку и к...
# 655    едкую дымку сдуло из города воздух в городе по...
# 656    бойтесь панков и китов как учителей учат борот...
# 657    в красноярске пропал высокий 16летний подросто...
# 658    мы вытащили новый suzuki jimny на военный поли...
# 659    ночью в серьезном пожаре выгорело бесхозное зд...
# 660    в красноярске ожидаются очень теплые выходные ...
# 661    депутаты отказали автомобилистам в скидке на о...
# 662    в красноярске сгорел автомобиль скорой помощи ...
# 663    в дивногорске меняют герб на нем не будет глав...
# 664    три инсайта после родов за что я осуждала моло...
# Name: text, Length: 665, dtype: object
#                                                              0
# Unnamed: 0                                                   0
# parced                                     2020-02-08 13:52:56
# link                      https://ngs24.ru/news/more/66485668/
# datenews                                   2020-02-08 12:42:26
# headline     Красноярская активистка направила обращение в ...
# altheadline          Ответ аппарата правительства ее рассмешил
# txtnewsfull  Лаборатория должна появиться в горах в 6 км от...
# views                                                      703
# comments                                                     9
# rating                        ЛАЙК1СМЕХ1УДИВЛЕНИЕ0ГНЕВ0ПЕЧАЛЬ0
# rubric                                                   Город
# tags         #Наталия Подоляк, #ядерное хранилище, #Краснод...
# text         красноярская активистка направила обращение в ...
# text_bow     [красноярский,  , активистка,  , направлять,  ...
# comment_len                                                496

# %% [markdown]
# Убираем стоп слова

# %%
import nltk
from nltk.corpus import stopwords
stop = stopwords.words('russian')

def data_Stop(text):
    return ' '.join([word for word in text.split(' ') if word not in stop])

data['text'] = data['text'].apply(lambda x: data_Stop(x))
print(data.text)
# Out:
# 0      красноярская активистка направила обращение пр...
# 1      молодые красноярцы сняли квартиру оборудовали ...
# 2      жд моста свободном оторвалась балка нависла до...
# 3      это грубое вторжение человека экологию жена эк...
# 4      красноярец прошелся капоту припаркованного авт...
# 5      казанью частном вертолете разбился депутат гос...
# 6      спасатели показали вытаскивают дна затонувшие ...
# 7      чаще жертвами становятся молодые мамы интервью...
# 8      суд присяжных оправдал парня убившего бабушку ...
# 9      бсмп прошли учения приемке пациентов коронавир...
# 10     вторые мире загрязнению вчерашний смог вывел к...
# 11     запрет youtube угроза штрафа датчики увольнени...
# 12     младенца упал баллон гелием девочка боролась ж...
# 13     плати 12 лет делу эксдепутата аркадия волкова ...
# 14     попытался убить обокрал дивногорца приговорили...
# 15     80летний пенсионер красноярска устраивает марш...
# 16     красноярских детей начали закалять орви йогой ...
# 17     главный прокурор края уходит отставку источник...
# 18     телефонный мошенник личиной банковского работн...
# 19     сибгу решетнева прошли обыски данным телеграмк...
# 20     надбавка алиментам путин обязал родителей обес...
# 21     выходных красноярцы смогут наблюдать рекордно ...
# 22     красноярске мусоропровод выкинули крольчиху сп...
# 23     красноярка перестала платить коммуналку кредит...
# 24     едкую дымку сдуло города воздух городе чистый ...
# 25     бойтесь панков китов учителей учат бороться су...
# 26     красноярске пропал высокий 16летний подросток ...
# 27     вытащили новый suzuki jimny военный полигон эт...
# 28     ночью серьезном пожаре выгорело бесхозное здан...
# 29     красноярске ожидаются очень теплые выходные во...
#                              ...
# 635    красноярец прошелся капоту припаркованного авт...
# 636    казанью частном вертолете разбился депутат гос...
# 637    спасатели показали вытаскивают дна затонувшие ...
# 638    чаще жертвами становятся молодые мамы интервью...
# 639    суд присяжных оправдал парня убившего бабушку ...
# 640    бсмп прошли учения приемке пациентов коронавир...
# 641    вторые мире загрязнению вчерашний смог вывел к...
# 642    запрет youtube угроза штрафа датчики увольнени...
# 643    младенца упал баллон гелием девочка боролась ж...
# 644    плати 12 лет делу эксдепутата аркадия волкова ...
# 645    попытался убить обокрал дивногорца приговорили...
# 646    80летний пенсионер красноярска устраивает марш...
# 647    красноярских детей начали закалять орви йогой ...
# 648    главный прокурор края уходит отставку источник...
# 649    телефонный мошенник личиной банковского работн...
# 650    сибгу решетнева прошли обыски данным телеграмк...
# 651    надбавка алиментам путин обязал родителей обес...
# 652    выходных красноярцы смогут наблюдать рекордно ...
# 653    красноярске мусоропровод выкинули крольчиху сп...
# 654    красноярка перестала платить коммуналку кредит...
# 655    едкую дымку сдуло города воздух городе чистый ...
# 656    бойтесь панков китов учителей учат бороться су...
# 657    красноярске пропал высокий 16летний подросток ...
# 658    вытащили новый suzuki jimny военный полигон эт...
# 659    ночью серьезном пожаре выгорело бесхозное здан...
# 660    красноярске ожидаются очень теплые выходные во...
# 661    депутаты отказали автомобилистам скидке осаго ...
# 662    красноярске сгорел автомобиль скорой помощи пр...
# 663    дивногорске меняют герб нем главного символа г...
# 664    инсайта родов осуждала молодых мам сама стала ...
# Name: text, Length: 665, dtype: object

# %% [markdown]
# Лемматизация и токенизация

# %%
from pymystem3 import Mystem
m = Mystem()
# применяем лемматизацию
data['text_bow'] = data['text'].apply(lambda x: m.lemmatize(x))
data.head(1).T
# заодно посчитаем длину новости
data['comment_len'] = data['text_bow'].apply(len)

# %% [markdown]
# Биграммы

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/09/ed/b59a2edde05b7f5755ea68648487c150c7c742361e9c8733c6d4ca005020/gensim-3.8.1-cp37-cp37m-win_amd64.whl (24.2MB)
# Requirement already satisfied: scipy>=0.18.1 in c:\python\anaconda3\lib\site-packages (from gensim) (1.2.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\python\anaconda3\lib\site-packages (from gensim) (1.16.4)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/0c/09/735f2786dfac9bbf39d244ce75c0313d27d4962e71e0774750dc809f2395/smart_open-1.9.0.tar.gz (70kB)
# Requirement already satisfied: six>=1.5.0 in c:\python\anaconda3\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: boto>=2.32 in c:\python\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: requests in c:\python\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Collecting boto3 (from smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/73/c1/c25300e0afbe36f550d82affc0d1705076e9ea909ef33e8dd1f7147df10b/boto3-1.12.0-py2.py3-none-any.whl (128kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\python\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\python\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\python\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.11.28)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
# Collecting botocore<1.16.0,>=1.15.0 (from boto3->smart-open>=1.8.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/a4/ba/236f25b9200f0cda4842585205b566979484d38927a8a302cc5c1beea10c/botocore-1.15.0-py2.py3-none-any.whl (5.9MB)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\python\anaconda3\lib\site-packages (from botocore<1.16.0,>=1.15.0->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\python\anaconda3\lib\site-packages (from botocore<1.16.0,>=1.15.0->boto3->smart-open>=1.8.1->gensim) (2.8.0)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\A4F7~1\AppData\Local\pip\Cache\wheels\ab\10\93\5cff86f5b721d77edaecc29959b1c60d894be1f66d91407d28
# Successfully built smart-open
# Installing collected packages: jmespath, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto3-1.12.0 botocore-1.15.0 gensim-3.8.1 jmespath-0.9.4 s3transfer-0.3.3 smart-open-1.9.0

# %%
from gensim import corpora, models
# создаём объект для генерации биграм
# min_count и threshold нужны для обрезки слишком редких
bigram = models.Phrases(data.text_bow, min_count=3, threshold=5)
# оборачиваем объект для быстрой обработки текста
bigram_mod = models.phrases.Phraser(bigram)
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]
# и генерируем текст с биграммами
texts = make_bigrams(data.text_bow)

# %% [markdown]
# Фильтрация по частоте

# %%
from gensim import corpora, models
# составляем словарь из терминов
dictionary = corpora.Dictionary(texts)
# и убираем слишком редкие (no_below) и слишком частые (no_above)
dictionary.filter_extremes(no_below=3, no_above=0.4)
# наконец, составляем финальный готовый корпус
corpus = [dictionary.doc2bow(text) for text in texts]
# и не забываем сохранить
import pickle
with open('corpus', 'wb') as f:
    pickle.dump(corpus, f)

# %% [markdown]
# Построение модели

# %%
from gensim import corpora, models

ldamodel = models.ldamodel.LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=30,
    passes=5
    )

ldamodel.save("ldamodel_30_bigrams_long_comments")

topics = ldamodel.show_topics(
    num_topics=30,
    num_words=100,
    formatted=False
    )

with open('lda_30_topics_bigrams_long_comments', 'wb') as f:
    pickle.dump(topics, f)

# %% [markdown]
# Визуализация

# %%
import pickle   
with open('lda_30_topics_bigrams_long_comments', 'rb') as f:
    lda_30_topics = pickle.load(f)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
plt.style.use('ggplot')          # задаём красивый стиль для графиков matplotlib-а
# %matplotlib inline

def plotWordCloud(topic_number):
    """
    Строит визуализацию слов на основе текстов топиков
    """
    # получаем частоты и слова топика
    text = dict(lda_30_topics[topic_number][1])
    
    # строим облако слов
    wordcloud = WordCloud(
        background_color="white",
        max_words=100,
    width=900,
    height=900,
    collocations=False)
    wordcloud = wordcloud.generate_from_frequencies(text)
    plt.figure(figsize=(15, 10))
    plt.title("Топик номер {}".format(topic_number))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off");

# %%
for i in range(5):
    plotWordCloud(topic_number=i)
